# %%
import base64
import requests
import json
from config import sportskey
from config import password
from config import gkey
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import linregress
import os
from ohmysportsfeedspy import MySportsFeeds
import gmaps

msf = MySportsFeeds(version="2.0")
msf.authenticate(sportskey, "MYSPORTSFEEDS")

# %%
output = msf.msf_get_data(league='nba',season='2018-2019-regular',feed='seasonal_player_stats',format='json')

# %%
num_records = len(output["playerStatsTotals"])

# %%
stats_df = pd.DataFrame(columns=['Name', 'Age', 'Birth City', 'Birth Country', 'Birth Lat', 'Birth Lng', 'College', 'College Lat', 'College Lng', 'Ability Score'], index = np.arange(num_records))
stats_df
# Out:
#     Name  Age Birth City Birth Country Birth Lat Birth Lng College  \
# 0    NaN  NaN        NaN           NaN       NaN       NaN     NaN
# 1    NaN  NaN        NaN           NaN       NaN       NaN     NaN
# 2    NaN  NaN        NaN           NaN       NaN       NaN     NaN
# 3    NaN  NaN        NaN           NaN       NaN       NaN     NaN
# 4    NaN  NaN        NaN           NaN       NaN       NaN     NaN
# ..   ...  ...        ...           ...       ...       ...     ...
# 876  NaN  NaN        NaN           NaN       NaN       NaN     NaN
# 877  NaN  NaN        NaN           NaN       NaN       NaN     NaN
# 878  NaN  NaN        NaN           NaN       NaN       NaN     NaN
# 879  NaN  NaN        NaN           NaN       NaN       NaN     NaN
# 880  NaN  NaN        NaN           NaN       NaN       NaN     NaN
#
#     College Lat College Lng Ability Score
# 0           NaN         NaN           NaN
# 1           NaN         NaN           NaN
# 2           NaN         NaN           NaN
# 3           NaN         NaN           NaN
# 4           NaN         NaN           NaN
# ..          ...         ...           ...
# 876         NaN         NaN           NaN
# 877         NaN         NaN           NaN
# 878         NaN         NaN           NaN
# 879         NaN         NaN           NaN
# 880         NaN         NaN           NaN
#
# [881 rows x 10 columns]

# %%
output["playerStatsTotals"][2]["player"]["firstName"]
# Out:
# 'Jaylen'

# %%
for index, row in stats_df.iterrows():
    for x in range(num_records):
        stats_df.loc[x, 'Name'] = output["playerStatsTotals"][x]["player"]["firstName"] + " " + output["playerStatsTotals"][x]["player"]["lastName"]
        stats_df.loc[x, 'Age'] = output["playerStatsTotals"][x]["player"]["age"]
        stats_df.loc[x, 'Birth City'] = output["playerStatsTotals"][x]["player"]["birthCity"]
        stats_df.loc[x, 'Birth Country'] = output["playerStatsTotals"][x]["player"]["birthCountry"]
        stats_df.loc[x, 'College'] = output["playerStatsTotals"][x]["player"]["college"]
        stats_df.loc[x, 'Ability Score'] = output["playerStatsTotals"][x]["stats"]["rebounds"]["rebPerGame"] + output["playerStatsTotals"][x]["stats"]["offense"]["ptsPerGame"] + output["playerStatsTotals"][x]["stats"]["offense"]["astPerGame"] + output["playerStatsTotals"][x]["stats"]["defense"]["stlPerGame"] + output["playerStatsTotals"][x]["stats"]["defense"]["blkPerGame"]        

stats_df
# Out:
#                       Name Age         Birth City Birth Country Birth Lat  \
# 0             Alex Abrines  26  Palma de Mallorca         Spain       NaN
# 1               Quincy Acy  29          Tyler, TX           USA       NaN
# 2             Jaylen Adams  23       Elkridge, MD           USA       NaN
# 3             Steven Adams  26            Rotorua   New Zealand       NaN
# 4              Bam Adebayo  22         Newark, NJ           USA       NaN
# ..                     ...  ..                ...           ...       ...
# 876           Nate Wolters  28      St. Cloud, MN           USA       NaN
# 877           Kenny Wooten  21        Manteca, CA           USA       NaN
# 878         Brandan Wright  32      Nashville, TN           USA       NaN
# 879  Justin Wright-Foreman  22      Laurelton, NY           USA       NaN
# 880            Tony Wroten  27        Seattle, WA           USA       NaN
#
#     Birth Lng                        College College Lat College Lng  \
# 0         NaN                           None         NaN         NaN
# 1         NaN              Baylor University         NaN         NaN
# 2         NaN                           None         NaN         NaN
# 3         NaN       University of Pittsburgh         NaN         NaN
# 4         NaN         University of Kentucky         NaN         NaN
# ..        ...                            ...         ...         ...
# 876       NaN  South Dakota State University         NaN         NaN
# 877       NaN                         Oregon         NaN         NaN
# 878       NaN   University of North Carolina         NaN         NaN
# 879       NaN                        Hofstra         NaN         NaN
# 880       NaN       University of Washington         NaN         NaN
#
#     Ability Score
# 0             8.1
# 1             5.5
# 2             7.4
# 3            27.4
# 4            20.1
# ..            ...
# 876             0
# 877             0
# 878             0
# 879             0
# 880             0
#
# [881 rows x 10 columns]

# %%
# saves df to csv
output_data_file = "Output csv's/2019 nba stats.csv"
stats_df.to_csv(output_data_file)

# %%
# saves csv to df so I don't have to run above cells every time
file_path = os.path.join("Output csv's", "2019 nba stats.csv")
statscsv_df = pd.read_csv(file_path)

# %%
ability_df = statscsv_df.loc[statscsv_df["Ability Score"] > 0]
ability_df
# Out:
#      Unnamed: 0          Name  Age         Birth City Birth Country  \
# 0             0  Alex Abrines   26  Palma de Mallorca         Spain
# 1             1    Quincy Acy   29          Tyler, TX           USA
# 2             2  Jaylen Adams   23       Elkridge, MD           USA
# 3             3  Steven Adams   26            Rotorua   New Zealand
# 4             4   Bam Adebayo   22         Newark, NJ           USA
# ..          ...           ...  ...                ...           ...
# 617         617  Tyler Zeller   30        Visalia, CA           USA
# 618         618       Qi Zhou   24                NaN           NaN
# 619         619    Ante Zizic   23              Split       Croatia
# 620         620   Ivica Zubac   23             Mostar       Croatia
# 621         621   Ivica Zubac   23             Mostar       Croatia
#
#      Birth Lat  Birth Lng                       College  College Lat  \
# 0          NaN        NaN                           NaN          NaN
# 1          NaN        NaN             Baylor University          NaN
# 2          NaN        NaN                           NaN          NaN
# 3          NaN        NaN      University of Pittsburgh          NaN
# 4          NaN        NaN        University of Kentucky          NaN
# ..         ...        ...                           ...          ...
# 617        NaN        NaN  University of North Carolina          NaN
# 618        NaN        NaN                           NaN          NaN
# 619        NaN        NaN                           NaN          NaN
# 620        NaN        NaN                           NaN          NaN
# 621        NaN        NaN                           NaN          NaN
#
#      College Lng  Ability Score
# 0            NaN            8.1
# 1            NaN            5.5
# 2            NaN            7.4
# 3            NaN           27.4
# 4            NaN           20.1
# ..           ...            ...
# 617          NaN           17.8
# 618          NaN            2.0
# 619          NaN           14.7
# 620          NaN           15.2
# 621          NaN           19.9
#
# [616 rows x 11 columns]

# %%
age_count = ability_df["Age"].value_counts()
age_count
age_count = age_count.to_frame()
age_count = age_count.reset_index()
age_count = age_count.rename(columns={"index":"Age", "Age":"Number of Players of that Age"})
age_count
age_count = age_count.sort_values("Age")
age_count
# Out:
#     Age  Number of Players of that Age
# 15   20                              8
# 11   21                             23
# 8    22                             38
# 5    23                             48
# 0    24                             65
# 4    25                             53
# 2    26                             56
# 1    27                             59
# 6    28                             41
# 3    29                             54
# 9    30                             33
# 7    31                             39
# 13   32                             21
# 12   33                             23
# 10   34                             25
# 14   35                             11
# 18   36                              4
# 16   37                              5
# 19   38                              2
# 17   39                              5
# 21   40                              1
# 20   41                              1
# 22   43                              1

# %%
plt.bar(age_count["Age"], age_count["Number of Players of that Age"])
plt.xlabel('Age')
plt.ylabel('Number of Players of that Age')
plt.title("Amount of 2019 NBA Players of Each Age")
plt.savefig("Figures/num ages 2019 nba.png")

# %%
x_values = ability_df["Age"]
y_values = ability_df["Ability Score"]

# Adds the linear regression equation and line to plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#stores regression line
regress_values = x_values * slope + intercept
# creates the formula of the line that will appear
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plots points
plt.scatter(x_values,y_values)
# plots regression line, ”r-“ makes the line a continuous
plt.plot(x_values,regress_values,"r-")
# makes the formula appear
plt.annotate(line_eq,(34,34),fontsize=15,color="red")
plt.xlabel("Age")
plt.ylabel("Ability Score")
plt.title("Age vs. Ability Score for 2019 NBA Players")
print(f"The r-squared value is: {rvalue**2}")
plt.savefig("Figures/ability score 2019 nba.png")
plt.show()
# Out:
# The r-squared value is: 0.009414582548116255

# %%
sorted_df = statscsv_df.sort_values("Ability Score", ascending = False)
del sorted_df['Unnamed: 0']

# %%
top_100 = sorted_df.iloc[0:100]
top_100

x_values = top_100["Age"]
y_values = top_100["Ability Score"]

# Adds the linear regression equation and line to plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#stores regression line
regress_values = x_values * slope + intercept
# creates the formula of the line that will appear
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plots points
plt.scatter(x_values,y_values)
# plots regression line, ”r-“ makes the line a continuous
plt.plot(x_values,regress_values,"r-")
# makes the formula appear
plt.annotate(line_eq,(34,34),fontsize=15,color="red")
plt.xlabel("Age")
plt.ylabel("Ability Score")
plt.title("Age vs. Ability Score for Top 100 2019 NBA Players")
print(f"The r-squared value is: {rvalue**2}")
plt.savefig("Figures/ability score top 100 2019 nba.png")
plt.show()
# Out:
# The r-squared value is: 0.0044050091120690785

# %%
sorted_df_birth = sorted_df[sorted_df['Birth City'].notna()]
sorted_df_birth = sorted_df_birth[sorted_df_birth['Birth Country'].notna()]
sorted_df_birth

top_200_birth = sorted_df_birth.iloc[0:200]
top_200_birth
# Out:
#                       Name  Age        Birth City Birth Country  Birth Lat  \
# 237           James Harden   30   Los Angeles, CA           USA        NaN
# 18   Giannis Antetokounmpo   25            Athens        Greece        NaN
# 178            Joel Embiid   26           Yaounde      Cameroon        NaN
# 592      Russell Westbrook   31    Long Beach, CA           USA        NaN
# 296           LeBron James   35         Akron, OH           USA        NaN
# ..                     ...  ...               ...           ...        ...
# 52        Patrick Beverley   31       Chicago, IL           USA        NaN
# 85          Reggie Bullock   29     Baltimore, MD           USA        NaN
# 530           Marcus Smart   26  Flower Mound, TX           USA        NaN
# 617           Tyler Zeller   30       Visalia, CA           USA        NaN
# 454           Kelly Olynyk   28           Toronto        Canada        NaN
#
#      Birth Lng                                College  College Lat  \
# 237        NaN               Arizona State University          NaN
# 18         NaN                                    NaN          NaN
# 178        NaN                   University of Kansas          NaN
# 592        NaN  University of California, Los Angeles          NaN
# 296        NaN                                    NaN          NaN
# ..         ...                                    ...          ...
# 52         NaN                 University of Arkansas          NaN
# 85         NaN           University of North Carolina          NaN
# 530        NaN              Oklahoma State University          NaN
# 617        NaN           University of North Carolina          NaN
# 454        NaN                     Gonzaga University          NaN
#
#      College Lng  Ability Score
# 237          NaN           52.9
# 18           NaN           48.9
# 178          NaN           47.4
# 592          NaN           47.1
# 296          NaN           46.1
# ..           ...            ...
# 52           NaN           18.0
# 85           NaN           18.0
# 530          NaN           17.9
# 617          NaN           17.8
# 454          NaN           17.7
#
# [200 rows x 10 columns]

# %%
# itterate through every index and row of df
for index, row in top_200_birth.iterrows():
# sets target place to the name of each player's birth location
    target_place = "{0},{1}".format(row['Birth City'], row['Birth Country'])
# sets parameters for url
    params = {
        "address": target_place,
        "key": gkey
    }
# if geocode can find the coordinates for the college, proceed, if not, output a print statement
    try:
        base_url = "https://maps.googleapis.com/maps/api/geocode/json"
# extracts contents of API
        response = requests.get(base_url, params = params).json()
# sets variable to the path to take within the API dictionary
        results = response['results'][0]["geometry"]["location"]
# adds the lat and lng of each location to the df
        top_200_birth.loc[index, 'Birth Lat'] = results["lat"]
        top_200_birth.loc[index, 'Birth Lng'] = results["lng"]
    except IndexError:
        print("Can't find coordinates of town... skipping")
# Out:
# /opt/anaconda3/envs/PythonData2020_1/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
top_200_birth
# Out:
#                       Name  Age        Birth City Birth Country  Birth Lat  \
# 237           James Harden   30   Los Angeles, CA           USA  34.052234
# 18   Giannis Antetokounmpo   25            Athens        Greece  37.983810
# 178            Joel Embiid   26           Yaounde      Cameroon   3.848032
# 592      Russell Westbrook   31    Long Beach, CA           USA  33.770050
# 296           LeBron James   35         Akron, OH           USA  41.081445
# ..                     ...  ...               ...           ...        ...
# 52        Patrick Beverley   31       Chicago, IL           USA  41.878114
# 85          Reggie Bullock   29     Baltimore, MD           USA  39.290385
# 530           Marcus Smart   26  Flower Mound, TX           USA  33.014567
# 617           Tyler Zeller   30       Visalia, CA           USA  36.330228
# 454           Kelly Olynyk   28           Toronto        Canada  43.653226
#
#       Birth Lng                                College  College Lat  \
# 237 -118.243685               Arizona State University          NaN
# 18    23.727539                                    NaN          NaN
# 178   11.502075                   University of Kansas          NaN
# 592 -118.193740  University of California, Los Angeles          NaN
# 296  -81.519005                                    NaN          NaN
# ..          ...                                    ...          ...
# 52   -87.629798                 University of Arkansas          NaN
# 85   -76.612189           University of North Carolina          NaN
# 530  -97.096955              Oklahoma State University          NaN
# 617 -119.292058           University of North Carolina          NaN
# 454  -79.383184                     Gonzaga University          NaN
#
#      College Lng  Ability Score
# 237          NaN           52.9
# 18           NaN           48.9
# 178          NaN           47.4
# 592          NaN           47.1
# 296          NaN           46.1
# ..           ...            ...
# 52           NaN           18.0
# 85           NaN           18.0
# 530          NaN           17.9
# 617          NaN           17.8
# 454          NaN           17.7
#
# [200 rows x 10 columns]

# %%
# saves df to csv
output_data_file2 = "Output csv's/birth loc nba 2019.csv"
top_200_birth.to_csv(output_data_file2)

# %%
# saves csv to df so I don't have to run above cells every time
file_path2 = os.path.join("Output csv's", "birth loc nba 2019.csv")
top_200_birth = pd.read_csv(file_path2)

# delete unnecessary column
del top_200_birth['Unnamed: 0']
top_200_birth
# Out:
#                       Name  Age        Birth City Birth Country  Birth Lat  \
# 0             James Harden   30   Los Angeles, CA           USA  34.052234
# 1    Giannis Antetokounmpo   25            Athens        Greece  37.983810
# 2              Joel Embiid   26           Yaounde      Cameroon   3.848032
# 3        Russell Westbrook   31    Long Beach, CA           USA  33.770050
# 4             LeBron James   35         Akron, OH           USA  41.081445
# ..                     ...  ...               ...           ...        ...
# 195       Patrick Beverley   31       Chicago, IL           USA  41.878114
# 196         Reggie Bullock   29     Baltimore, MD           USA  39.290385
# 197           Marcus Smart   26  Flower Mound, TX           USA  33.014567
# 198           Tyler Zeller   30       Visalia, CA           USA  36.330228
# 199           Kelly Olynyk   28           Toronto        Canada  43.653226
#
#       Birth Lng                                College  College Lat  \
# 0   -118.243685               Arizona State University          NaN
# 1     23.727539                                    NaN          NaN
# 2     11.502075                   University of Kansas          NaN
# 3   -118.193740  University of California, Los Angeles          NaN
# 4    -81.519005                                    NaN          NaN
# ..          ...                                    ...          ...
# 195  -87.629798                 University of Arkansas          NaN
# 196  -76.612189           University of North Carolina          NaN
# 197  -97.096955              Oklahoma State University          NaN
# 198 -119.292058           University of North Carolina          NaN
# 199  -79.383184                     Gonzaga University          NaN
#
#      College Lng  Ability Score
# 0            NaN           52.9
# 1            NaN           48.9
# 2            NaN           47.4
# 3            NaN           47.1
# 4            NaN           46.1
# ..           ...            ...
# 195          NaN           18.0
# 196          NaN           18.0
# 197          NaN           17.9
# 198          NaN           17.8
# 199          NaN           17.7
#
# [200 rows x 10 columns]

# %%
# Access maps with unique API key
gmaps.configure(api_key=gkey)

# creates heat map of birth locations of NBA players since 1950
fig = gmaps.figure()
heatmap_layer = gmaps.heatmap_layer(top_200_birth[["Birth Lat", "Birth Lng"]])
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
sorted_df_college = sorted_df[sorted_df['College'].notna()]
sorted_df_college

top_200_college = sorted_df_college.iloc[0:200]
top_200_college
# Out:
#                     Name  Age       Birth City Birth Country  Birth Lat  \
# 237         James Harden   30  Los Angeles, CA           USA        NaN
# 178          Joel Embiid   26          Yaounde      Cameroon        NaN
# 592    Russell Westbrook   31   Long Beach, CA           USA        NaN
# 144        Anthony Davis   27      Chicago, IL           USA        NaN
# 212          Paul George   29     Palmdale, CA           USA        NaN
# ..                   ...  ...              ...           ...        ...
# 317           Tyus Jones   23   Burnsville, MN           USA        NaN
# 438       Shabazz Napier   28      Roxbury, MA           USA        NaN
# 134         Allen Crabbe   28  Los Angeles, CA           USA        NaN
# 325         Luke Kennard   23   Middletown, OH           USA        NaN
# 194  Dorian Finney-Smith   26   Portsmouth, VA           USA        NaN
#
#      Birth Lng                                College  College Lat  \
# 237        NaN               Arizona State University          NaN
# 178        NaN                   University of Kansas          NaN
# 592        NaN  University of California, Los Angeles          NaN
# 144        NaN                 University of Kentucky          NaN
# 212        NaN    California State University, Fresno          NaN
# ..         ...                                    ...          ...
# 317        NaN                        Duke University          NaN
# 438        NaN              University of Connecticut          NaN
# 134        NaN               University of California          NaN
# 325        NaN                        Duke University          NaN
# 194        NaN                  University of Florida          NaN
#
#      College Lng  Ability Score
# 237          NaN           52.9
# 178          NaN           47.4
# 592          NaN           47.1
# 144          NaN           45.8
# 212          NaN           42.8
# ..           ...            ...
# 317          NaN           15.0
# 438          NaN           14.9
# 134          NaN           14.9
# 325          NaN           14.9
# 194          NaN           14.9
#
# [200 rows x 10 columns]

# %%
# saves df to csv
output_data_file3 = "Output csv's/college nba 2019.csv"
top_200_college.to_csv(output_data_file3)

# %%
# saves csv to df so I don't have to run above cells every time
file_path3 = os.path.join("Output csv's", "college nba 2019.csv")
top_200_college = pd.read_csv(file_path3)

# delete unnecessary column
del top_200_college['Unnamed: 0']
top_200_college
# Out:
#                     Name  Age       Birth City Birth Country  Birth Lat  \
# 0           James Harden   30  Los Angeles, CA           USA        NaN
# 1            Joel Embiid   26          Yaounde      Cameroon        NaN
# 2      Russell Westbrook   31   Long Beach, CA           USA        NaN
# 3          Anthony Davis   27      Chicago, IL           USA        NaN
# 4            Paul George   29     Palmdale, CA           USA        NaN
# ..                   ...  ...              ...           ...        ...
# 195           Tyus Jones   23   Burnsville, MN           USA        NaN
# 196       Shabazz Napier   28      Roxbury, MA           USA        NaN
# 197         Allen Crabbe   28  Los Angeles, CA           USA        NaN
# 198         Luke Kennard   23   Middletown, OH           USA        NaN
# 199  Dorian Finney-Smith   26   Portsmouth, VA           USA        NaN
#
#      Birth Lng                                College  College Lat  \
# 0          NaN               Arizona State University    33.424240
# 1          NaN                   University of Kansas    38.954344
# 2          NaN  University of California, Los Angeles    34.068921
# 3          NaN                 University of Kentucky    38.030651
# 4          NaN    California State University, Fresno    36.813363
# ..         ...                                    ...          ...
# 195        NaN                        Duke University    36.001426
# 196        NaN              University of Connecticut    41.807741
# 197        NaN               University of California    37.871899
# 198        NaN                        Duke University    36.001426
# 199        NaN                  University of Florida    29.643633
#
#      College Lng  Ability Score
# 0    -111.928053           52.9
# 1     -95.255796           47.4
# 2    -118.445181           47.1
# 3     -84.503970           45.8
# 4    -119.746095           42.8
# ..           ...            ...
# 195   -78.938229           15.0
# 196   -72.253981           14.9
# 197  -122.258540           14.9
# 198   -78.938229           14.9
# 199   -82.354930           14.9
#
# [200 rows x 10 columns]

# %%
# itterate through every index and row of df
for index, row in top_200_college.iterrows():
# sets target place to the name of each player's college
    target_place = "{0}".format(row['College'])
# sets parameters for url
    params = {
        "address": target_place,
        "key": gkey
    }
# if geocode can find the coordinates for the college, proceed, if not, output a print statement
    try:
        base_url = "https://maps.googleapis.com/maps/api/geocode/json"
# extracts contents of API
        response = requests.get(base_url, params = params).json()
# sets variable to the path to take within the API dictionary
        results = response['results'][0]["geometry"]["location"]
# adds the lat and lng of each college to the df
        top_200_college.loc[index, 'College Lat'] = results["lat"]
        top_200_college.loc[index, 'College Lng'] = results["lng"]
    except IndexError:
        print("Can't find coordinates of school... skipping")
# Out:
# /opt/anaconda3/envs/PythonData2020_1/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
top_200_college
# Out:
#                     Name  Age       Birth City Birth Country  Birth Lat  \
# 237         James Harden   30  Los Angeles, CA           USA        NaN
# 178          Joel Embiid   26          Yaounde      Cameroon        NaN
# 592    Russell Westbrook   31   Long Beach, CA           USA        NaN
# 144        Anthony Davis   27      Chicago, IL           USA        NaN
# 212          Paul George   29     Palmdale, CA           USA        NaN
# ..                   ...  ...              ...           ...        ...
# 317           Tyus Jones   23   Burnsville, MN           USA        NaN
# 438       Shabazz Napier   28      Roxbury, MA           USA        NaN
# 134         Allen Crabbe   28  Los Angeles, CA           USA        NaN
# 325         Luke Kennard   23   Middletown, OH           USA        NaN
# 194  Dorian Finney-Smith   26   Portsmouth, VA           USA        NaN
#
#      Birth Lng                                College  College Lat  \
# 237        NaN               Arizona State University    33.424240
# 178        NaN                   University of Kansas    38.954344
# 592        NaN  University of California, Los Angeles    34.068921
# 144        NaN                 University of Kentucky    38.030651
# 212        NaN    California State University, Fresno    36.813363
# ..         ...                                    ...          ...
# 317        NaN                        Duke University    36.001426
# 438        NaN              University of Connecticut    41.807741
# 134        NaN               University of California    37.871899
# 325        NaN                        Duke University    36.001426
# 194        NaN                  University of Florida    29.643632
#
#      College Lng  Ability Score
# 237  -111.928053           52.9
# 178   -95.255796           47.4
# 592  -118.445181           47.1
# 144   -84.503970           45.8
# 212  -119.746095           42.8
# ..           ...            ...
# 317   -78.938229           15.0
# 438   -72.253980           14.9
# 134  -122.258540           14.9
# 325   -78.938229           14.9
# 194   -82.354930           14.9
#
# [200 rows x 10 columns]

# %%
# Access maps with unique API key
gmaps.configure(api_key=gkey)

# creates heat map of birth locations of NBA players since 1950
fig = gmaps.figure()
heatmap_layer = gmaps.heatmap_layer(top_200_college[["College Lat", "College Lng"]])
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
